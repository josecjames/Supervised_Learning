# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.model_selection import train_test_split

from super_plotfun import*

# %%
# read data from files

data = pd.read_csv('E:/python/Data/Automobile_data.csv')

# %%
from super_plotfun import data_distribution
data_distribution(data, 10,5)
# Out:
# E:\GithubProjects\Predictives\super_plotfun.py:21: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(noGraphRow, Ngraph_perRow, i + 1)
# E:\GithubProjects\Predictives\super_plotfun.py:21: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(noGraphRow, Ngraph_perRow, i + 1)
# E:\GithubProjects\Predictives\super_plotfun.py:21: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(noGraphRow, Ngraph_perRow, i + 1)
# ...

# %%
from super_plotfun import plotCorr
plotCorr(data, 8)

# %%
# regression Analysis
#data data types

'''
symboling rating corresponds to the degree to which the auto is more risky than 
its price indicates. Cars are initially assigned a risk factor
'''

print(data.symboling.unique())


'''
--Aim is to use K n neibor to class cars accrding to risk factors
--we will use risk as clusters 
'''

# %%
# chage data to numerical
print(data.dtypes)

for col in data.select_dtypes(include ='object'):
    try:
        data[col]=data[col].astype(str).astype(float)
    except:
        pass
print(data.dtypes)    
from sklearn.liner_model import LinerRegression
X = data['price']
